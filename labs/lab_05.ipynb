# %% [markdown]
# <img src="images/usm.jpg" width="480" height="240" align="left"/>

# %% [markdown]
# # MAT281 - Laboratorio N°05
#
# ## Objetivos de la clase
#
# * Reforzar los conceptos básicos de visualización.

# %% [markdown]
# ## Contenidos
#
# * [Problema 01](#p1)

# %% [markdown]
# ## Problema 01
#
# <img src="http://nelsoncos.com/wp-content/uploads/2017/02/sales-icon.png" width="360" height="360" align="center"/>
#
#
# EL conjunto de datos se denomina `company_sales_data.csv`, el cual contiene información tal como: número del mes, unidades, precio, etc.
#
# Lo primero es cargar el conjunto de datos y ver las primeras filas que lo componen:

# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(10,8)})

# %%
# cargar datos
#df = pd.read_csv(os.path.join("data","company_sales_data.csv"))
df = pd.read_csv("company_sales_data.csv")
df.dropna()
df.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %% [markdown]
# El objetivo es tratar de obtener la mayor información posible de este conjunto de datos. Para cumplir este objetivo debe resolver las siguientes problemáticas:
#
# **Observación.-** Puedes ocupar las librerías de Matplolib o Seaborn.

# %% [markdown]
# 1. Lea el "total_profit" de todos los meses, muéstrelo usando un gráfico lineal y un gráfico de dispersión.

# %%
total_profit_per_month = df[["month_number","total_profit"]]

#Grafico Lineal
sns.lineplot(
    x = "month_number",
    y = "total_profit",
    data = total_profit_per_month,
    ci = None
)
# Out:
# <AxesSubplot:xlabel='month_number', ylabel='total_profit'>

# %%
#Grafico de dispersion
sns.scatterplot(
    x = "month_number",
    y = "total_profit",
    data = total_profit_per_month,
    ci = None
)
# Out:
# <AxesSubplot:xlabel='month_number', ylabel='total_profit'>

# %% [markdown]
# 2. Lea todos los datos de ventas de productos y muéstrelos utilizando un gráfico multilínea.

# %%
ventas = df.drop(["month_number","total_units","total_profit"],axis=1)

sns.lineplot(data=ventas)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 3. Lea los datos de ventas de productos de "facecream" y "facewash" y muéstrelos usando el gráfico de barras.

# %%
data_face = df[["facecream","facewash"]]
sns.barplot(
        x = "facecream",
        y = "facewash",
        data = data_face
)
# Out:
# <AxesSubplot:xlabel='facecream', ylabel='facewash'>

# %% [markdown]
# 4. Lea todos los datos de ventas de productos y muéstrelos utilizando un gráfico box-plot.

# %%
data_st = df.drop(["month_number"],axis=1)
sns.boxplot(data = data_st)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Note que el gráfico de Box Plot no se puede visualizar de buena manera debido a la diferencia existente entre total_profit y total_units con las otras variables, ante esto quitaremos total_profit de nuestro análisis para poder visualizar de buena forma el BoxPlot

# %%
data_st = df.drop(["month_number","total_profit","total_units"],axis=1)
sns.boxplot(data = data_st)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 5. Calcule los datos de ventas totales del año pasado para cada producto y muéstrelos usando un gráfico circular

# %% [markdown]
# Los datos de  ventas totales vienen datos por la suma en cada columna

# %%
total  =df.drop(["month_number","total_profit","total_units"],axis=1)

total_cat = total.sum()
total_cat.plot.pie(autopct="%.1f%%");
